# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# `sns.set()` is a simple command from the **Seaborn** library in Python used for **setting default plot styles**.
#
# ### ✅ Simply put:
#
# ```python
# sns.set()
# ```
#
# ➡️ **Makes your plots look better** by applying Seaborn's default style settings (like gridlines, colors, fonts, etc.).
#
# ---
#
# ### 🧠 Behind the scenes, it:
#
# * Changes **Matplotlib**'s default theme.
# * Adds **nicer fonts**, **gridlines**, **colors**, and **figure sizes**.
#
# ---
#
# ### 💡 Example:
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# sns.set()  # apply seaborn styling
#
# tips = sns.load_dataset("tips")
# sns.scatterplot(data=tips, x="total_bill", y="tip")
#
# plt.show()
# ```
#
# ✅ This will show a better-styled plot than if you didn't call `sns.set()`.
#
# ---
#
# If you want specific styles, you can use:
#
# ```python
# sns.set(style="whitegrid")  # other options: "darkgrid", "white", "dark", "ticks"
# ```
#
# Let me know if you want a visual difference or custom styling!

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1)
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# Addition

# %%
vector_1 = np.asarray([0,0,4,5])
vector_2 = np.asarray([0,0,3,4])
sum = vector_1+vector_2
print(sum)
# Out:
# [0 0 7 9]

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='y')
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,7,9,scale_units='xy',angles='xy',scale=1,color='r')


plt.xlim(-9,9)
plt.ylim(-9,9)
plt.show()

# %% [markdown]
# Subtraction-:

# %%
vector_1 = np.asarray([0,0,4,5])
vector_2 = np.asarray([0,0,3,4])
difference = vector_1-vector_2
print(difference)
# Out:
# [0 0 1 1]

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='y')
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,1,1,scale_units='xy',angles='xy',scale=1,color='r')


plt.xlim(-9,9)
plt.ylim(-9,9)
plt.show()

# %% [markdown]
# Scalar Multiplication:

# %%
vector_1 = np.asarray([0,0,4,5])
scalar = 3
multiplication= scalar*vector_1
print(multiplication)
# Out:
# [ 0  0 12 15]

# %%
plt.quiver(0,0,4,5,scale_units='xy',angles='xy',scale=1,color='g')
plt.quiver(0,0,12,15,scale_units='xy',angles='xy',scale=1,color='r')


plt.xlim(-9,20)
plt.ylim(-9,20)
plt.show()
