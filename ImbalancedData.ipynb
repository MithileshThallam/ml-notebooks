# %% [markdown]
# Imbalanced data refers to a situation where the classes (output labels) in a dataset are not represented equally. For example, in a binary classification problem with 2,000 samples, if 1,800 are labeled "yes" and only 200 are labeled "no", the dataset is heavily biased toward the "yes" class. This imbalance can lead to poor performance in machine learning models, as they may become biased toward the majority class and ignore the minority class.
#
# To handle this, we can use techniques like random sampling, which includes:
#
# Under-sampling: Reducing the number of samples in the majority class.
#
# Over-sampling: Increasing the number of samples in the minority class (e.g., duplicating or using techniques like SMOTE).
#
# Balancing the dataset helps models learn patterns from all classes more effectively, improving generalization and accuracy.

# %%
import pandas as pd

# %%
df = pd.read_csv('credit_data.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (75357, 31)

# %%
df.Class.value_counts()
# Out:
# Class
# 0.0    75173
# 1.0      183
# Name: count, dtype: int64

# %% [markdown]
# 0-> legit transaction
# 1-> fraud transaction
#
# ---

# %%
legit = df[df['Class']==0.0]
fraud =df[df['Class']==1.0]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (75173, 31)
# (183, 31)

# %% [markdown]
# We are doing under sampling

# %%
legit_sample = legit.sample(n=200)
print(legit_sample.shape)
# Out:
# (200, 31)

# %%
new_df = pd.concat([legit_sample,fraud],axis=0)
new_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 45213  42253 -0.213029  0.021637  1.627503 -1.256530 -0.607742 -0.097723
# 6363    7579 -0.510254  1.142216  2.104981  1.183339  0.141866 -0.099184
# 13031  22887  1.191476 -0.256718  1.263408 -0.387676 -1.406036 -1.078807
# 42919  41297  1.136237 -1.689400  0.604514 -1.256140 -2.097257 -0.698626
# 22706  32392  1.118052  0.128877  0.326239  1.174001 -0.412781 -0.885088
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 45213 -0.051607  0.133230 -1.162040  ...  0.024824  0.037847 -0.133270
# 6363   0.488675 -0.201551  0.715624  ... -0.153139  0.092433 -0.055248
# 13031 -0.639869 -0.150443  3.069291  ... -0.121344  0.119941  0.032353
# 42919 -1.105469  0.034664 -1.718728  ... -0.231232 -0.814349  0.077075
# 22706  0.207696 -0.218763  0.049650  ...  0.108323  0.224724 -0.165783
#
#             V24       V25       V26       V27       V28  Amount  Class
# 45213 -0.008250 -0.014795 -0.369726  0.061453  0.043866   22.99    0.0
# 6363   0.252852 -0.346791 -0.474598  0.102470 -0.036466    5.00    0.0
# 13031  0.881295  0.401942 -0.759306  0.065533  0.036156   11.85    0.0
# 42919  0.441469 -0.054131 -0.450488 -0.004123  0.045043  172.28    0.0
# 22706  0.405295  0.656146 -0.303377  0.007670  0.032716   66.39    0.0
#
# [5 rows x 31 columns]

# %%
new_df.shape
# Out:
# (383, 31)

# %%
new_df.Class.value_counts()
# Out:
# Class
# 0.0    200
# 1.0    183
# Name: count, dtype: int64

# %%
new_df.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 73784  55279 -5.753852  0.577610 -6.312782  5.159401 -1.698320 -2.683286
# 73857  55311 -6.159607  1.468713 -6.850888  5.174706 -2.986704 -1.795054
# 74496  55614 -7.347955  2.397041 -7.572356  5.177819 -2.854838 -1.795239
# 74507  55618 -7.427924  2.948209 -8.678550  5.185303 -4.761090 -0.957095
# 74794  55760 -6.003422 -3.930731 -0.007045  1.714669  3.414667 -2.329583
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 73784 -7.934389  2.373550 -3.073079  ...  1.177852  0.175331 -1.211123
# 73857 -6.545072  2.621236 -3.605870  ...  1.061314  0.125737  0.589592
# 74496 -8.783235  0.437157 -3.740598  ... -0.175273  0.543325 -0.547955
# 74507 -7.773380  0.717309 -3.682359  ... -0.299847  0.610479  0.789023
# 74794 -1.901512 -2.746111  0.887673  ...  1.101671 -0.992494 -0.698259
#
#             V24       V25       V26       V27       V28  Amount  Class
# 73784 -0.446891 -0.405520 -0.165797  1.505516  0.359492    1.00    1.0
# 73857 -0.568731  0.582825 -0.042583  0.951130  0.158996    0.83    1.0
# 74496 -0.503722 -0.310933 -0.163986  1.197895  0.378187    0.83    1.0
# 74507 -0.564512  0.201196 -0.111225  1.144599  0.102280  130.44    1.0
# 74794  0.139898 -0.205151 -0.472412  1.775378 -0.104285  311.91    1.0
#
# [5 rows x 31 columns]
